# %%
import pandas as pd
import ipywidgets as widgets

# %%
data = pd.read_csv('../data/prefectos.csv', sep='|')

# %%
opciones = data['Provincia'].unique()

# %%
w = widgets.Dropdown(
    options = opciones,
    value = opciones[0],
    description='Provincias:',
    disabled=False,
)
display(w)
# Out:
# Dropdown(description='Paises:', options=('Azuay', 'Bolívar', 'Cañar', 'Carchi', 'Chimborazo', 'Cotopaxi', 'El …

# %%
data[(data['Provincia']== w.value)]
# Out:
#                             Nombre   Provincia      Partido FechaInicio  \
# 7                       Lucía Sosa  Esmeraldas          MUP        2014
# 94           Julio César Estupiñán  Esmeraldas  No contiene        1930
# 95                   Ricardo Plaza  Esmeraldas  No contiene        1932
# 96              José María Taborda  Esmeraldas  No contiene        1934
# 97                    César Concha  Esmeraldas  No contiene        1954
# 98                 Telémaco Cortés  Esmeraldas  No contiene        1956
# 99               Luis Alberto Díaz  Esmeraldas  No contiene        1958
# 100                  Segundo Salas  Esmeraldas  No contiene        1959
# 101         Roberto Luis Cervantes  Esmeraldas  No contiene        1960
# 102         Daniel Álvarez Tenorio  Esmeraldas  No contiene        1960
# 103  Pedro Vicente Maldonado López  Esmeraldas  No contiene        1962
# 104                 Rafael Aspiazu  Esmeraldas  No contiene        1963
# 105                 René Rodríguez  Esmeraldas  No contiene        1963
# 106               Gregorio Camacho  Esmeraldas  No contiene        1964
# 107              Gonzalo Gutiérrez  Esmeraldas  No contiene        1964
# 108                 Bolívar Drouet  Esmeraldas  No contiene        1965
# 109                    Jorge Jalil  Esmeraldas  No contiene        1967
# 110                 Tiberio Patiño  Esmeraldas  No contiene        1970
# 111               Maximiliano Haas  Esmeraldas  No contiene       1970
# 112              Luis Alberto Raad  Esmeraldas  No contiene        1970
# 113                 Luis Zatizabal  Esmeraldas  No contiene        1997
# 114              Ricardo Estupiñán  Esmeraldas  No contiene        1977
# 115          Francisco Mejía Villa  Esmeraldas  No contiene        1978
# 116                  Jorge Campaín  Esmeraldas  No contiene        1970
# 117                Jorge Chiriboga  Esmeraldas  No contiene        1983
# 118          Francisco Mejía Villa  Esmeraldas  No contiene        1988
# 119             David Medina Rojas  Esmeraldas  No contiene        1991
# 120                    Carlos Saúd  Esmeraldas  No contiene        1992
# 121                      René Rhor  Esmeraldas  No contiene        1996
# 122                   Homero López  Esmeraldas  No contiene        2000
# 123                     Lucía Sosa  Esmeraldas  No contiene        2005
# 124                   Rafael Erazo  Esmeraldas  No contiene        2013
# 125                     Lucía Sosa  Esmeraldas  No contiene        2014
#
#        FechaFin
# 7          2019
# 94         1932
# 95         1933
# 96         1935
# 97         1956
# 98         1958
# 99         1959
# 100        1960
# 101        1960
# 102        1962
# 103        1963
# 104        1963
# 105        1964
# 106        1964
# 107        1965
# 108        1967
# 109        1970
# 110        1974
# 111  Actualidad
# 112  Actualidad
# 113  Actualidad
# 114        1978
# 115        1983
# 116  Actualidad
# 117        1988
# 118        1991
# 119        1992
# 120        1996
# 121        2000
# 122        2005
# 123        2013
# 124        2014
# 125  Actualidad
